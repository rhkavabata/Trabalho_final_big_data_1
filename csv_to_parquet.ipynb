# %%
df_Categories = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Categories.csv")
df_Customers = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Customers.csv")
df_Employees = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Employees.csv")
df_EmployeeTerritories = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/EmployeeTerritories.csv")
df_OrderDetails = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/OrderDetails.csv")
df_Orders = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Orders.csv")
df_Products = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Products.csv")
df_Region = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Region.csv")
df_Shippers = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Shippers.csv")
df_Suppliers = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Suppliers.csv")
df_Territories = spark.read.format("csv").option(
    "header", "true").option("inferschema", "false").option("sep", ",").load("/FileStore/tables/Territories.csv")


df_Categories.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Categories")
df_Customers.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Customers")
df_Employees.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Employees")
df_EmployeeTerritories.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/EmployeeTerritories")
df_OrderDetails.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/OrderDetails")
df_Orders.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Orders")
df_Products.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Products")
df_Region.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Region")
df_Shippers.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Shippers")
df_Suppliers.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Suppliers")
df_Territories.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Territories")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-3091147154900616> in <cell line: 25>()
#      23
#      24
# ---> 25 df_Categories.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Categories")
#      26 df_Customers.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Customers")
#      27 df_Employees.write.format("parquet").option("header", "true").save("/FileStore/tables/Trusted/Employees")
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# ...

# %% [markdown]
# ## Criação da tabela dimensão Order Details

# %%
df_OrderDetails_fact = df_OrderDetails.join(df_Products, ['ProductID']) \
                                 .join(df_Categories, ['CategoryID']) \
                                 .join(df_Suppliers, ['SupplierID'])

# %%
df_OrderDetails_fact.printSchema()
# Out:
# root
#  |-- SupplierID: string (nullable = true)
#  |-- CategoryID: string (nullable = true)
#  |-- ProductID: string (nullable = true)
#  |-- OrderID: string (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- Quantity: string (nullable = true)
#  |-- Discount: string (nullable = true)
#  |-- ProductName: string (nullable = true)
#  |-- QuantityPerUnit: string (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- UnitsInStock: string (nullable = true)
#  |-- UnitsOnOrder: string (nullable = true)
#  |-- ReorderLevel: string (nullable = true)
#  |-- Discontinued: string (nullable = true)
#  |-- CategoryName: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Picture: string (nullable = true)
#  |-- CompanyName: string (nullable = true)
#  |-- ContactName: string (nullable = true)
#  |-- ContactTitle: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City: string (nullable = true)
# ...

# %% [markdown]
# ## Criação da tabela dimensão Employees

# %%
df_employees_fact = df_Employees.join(df_EmployeeTerritories, df_Employees.Employee == df_EmployeeTerritories.EmployeeID) \
                                   .join(df_Territories, df_EmployeeTerritories.TerritoryID == df_Territories.TerritoryID) \
                                   .join(df_Region, df_Territories.RegionID == df_Region.RegionID)

# %%
df_employees_fact.printSchema()
# Out:
# root
#  |-- Employee: string (nullable = true)
#  |-- LastName: string (nullable = true)
#  |-- FirstName: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- TitleOfCourtesy: string (nullable = true)
#  |-- BirthDate: string (nullable = true)
#  |-- HireDate: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- PostalCode: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- HomePhone: string (nullable = true)
#  |-- Extension: string (nullable = true)
#  |-- Photo: string (nullable = true)
#  |-- Notes: string (nullable = true)
#  |-- ReportsTo: string (nullable = true)
#  |-- PhotoPath: string (nullable = true)
#  |-- EmployeeID: string (nullable = true)
#  |-- TerritoryID: string (nullable = true)
#  |-- TerritoryID: string (nullable = true)
#  |-- TerritoryDescription: string (nullable = true)
#  |-- RegionID: string (nullable = true)
# ...

# %% [markdown]
# ## Criação da tabela dimensão Customers

# %%
df_Customers.fact = df_Customers.join()
